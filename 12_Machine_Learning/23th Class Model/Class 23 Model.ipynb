# %% [markdown]
# # Import Libraies

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# # Load Dataset

# %%
data = pd.read_csv("FuelConsumption.csv")

# %%
data.head()
# Out:
#    MODELYEAR   MAKE       MODEL VEHICLECLASS  ENGINESIZE  CYLINDERS  \
# 0       2014  ACURA         ILX      COMPACT         2.0          4
# 1       2014  ACURA         ILX      COMPACT         2.4          4
# 2       2014  ACURA  ILX HYBRID      COMPACT         1.5          4
# 3       2014  ACURA     MDX 4WD  SUV - SMALL         3.5          6
# 4       2014  ACURA     RDX AWD  SUV - SMALL         3.5          6
#
#   TRANSMISSION FUELTYPE  FUELCONSUMPTION_CITY  FUELCONSUMPTION_HWY  \
# 0          AS5        Z                   9.9                  6.7
# 1           M6        Z                  11.2                  7.7
# 2          AV7        Z                   6.0                  5.8
# 3          AS6        Z                  12.7                  9.1
# 4          AS6        Z                  12.1                  8.7
#
#    FUELCONSUMPTION_COMB  FUELCONSUMPTION_COMB_MPG  CO2EMISSIONS
# 0                   8.5                        33           196
# 1                   9.6                        29           221
# 2                   5.9                        48           136
# 3                  11.1                        25           255
# 4                  10.6                        27           244

# %%
df = data.copy()

# %% [markdown]
# # Exploratory Data Analysis

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1067 entries, 0 to 1066
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   MODELYEAR                 1067 non-null   int64
#  1   MAKE                      1067 non-null   object
#  2   MODEL                     1067 non-null   object
#  3   VEHICLECLASS              1067 non-null   object
#  4   ENGINESIZE                1067 non-null   float64
#  5   CYLINDERS                 1067 non-null   int64
#  6   TRANSMISSION              1067 non-null   object
#  7   FUELTYPE                  1067 non-null   object
#  8   FUELCONSUMPTION_CITY      1067 non-null   float64
#  9   FUELCONSUMPTION_HWY       1067 non-null   float64
#  10  FUELCONSUMPTION_COMB      1067 non-null   float64
#  11  FUELCONSUMPTION_COMB_MPG  1067 non-null   int64
#  12  CO2EMISSIONS              1067 non-null   int64
# dtypes: float64(4), int64(4), object(5)
# memory usage: 108.5+ KB

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.describe().T
# Out:
#                            count         mean        std     min      25%  \
# MODELYEAR                 1067.0  2014.000000   0.000000  2014.0  2014.00
# ENGINESIZE                1067.0     3.346298   1.415895     1.0     2.00
# CYLINDERS                 1067.0     5.794752   1.797447     3.0     4.00
# FUELCONSUMPTION_CITY      1067.0    13.296532   4.101253     4.6    10.25
# FUELCONSUMPTION_HWY       1067.0     9.474602   2.794510     4.9     7.50
# FUELCONSUMPTION_COMB      1067.0    11.580881   3.485595     4.7     9.00
# FUELCONSUMPTION_COMB_MPG  1067.0    26.441425   7.468702    11.0    21.00
# CO2EMISSIONS              1067.0   256.228679  63.372304   108.0   207.00
#
#                              50%      75%     max
# MODELYEAR                 2014.0  2014.00  2014.0
# ENGINESIZE                   3.4     4.30     8.4
# CYLINDERS                    6.0     8.00    12.0
# FUELCONSUMPTION_CITY        12.6    15.55    30.2
# FUELCONSUMPTION_HWY          8.8    10.85    20.5
# FUELCONSUMPTION_COMB        10.9    13.35    25.8
# FUELCONSUMPTION_COMB_MPG    26.0    31.00    60.0
# CO2EMISSIONS               251.0   294.00   488.0

# %%
df['MODELYEAR'].value_counts()
# Out:
# 2014    1067
# Name: MODELYEAR, dtype: int64

# %%
# df.drop(['MODELYEAR'],axis = 1,inplace = True) # We can do like this

df.drop(columns = ['MODELYEAR'],inplace = True)

# %%
df.head()
# Out:
#     MAKE       MODEL VEHICLECLASS  ENGINESIZE  CYLINDERS TRANSMISSION  \
# 0  ACURA         ILX      COMPACT         2.0          4          AS5
# 1  ACURA         ILX      COMPACT         2.4          4           M6
# 2  ACURA  ILX HYBRID      COMPACT         1.5          4          AV7
# 3  ACURA     MDX 4WD  SUV - SMALL         3.5          6          AS6
# 4  ACURA     RDX AWD  SUV - SMALL         3.5          6          AS6
#
#   FUELTYPE  FUELCONSUMPTION_CITY  FUELCONSUMPTION_HWY  FUELCONSUMPTION_COMB  \
# 0        Z                   9.9                  6.7                   8.5
# 1        Z                  11.2                  7.7                   9.6
# 2        Z                   6.0                  5.8                   5.9
# 3        Z                  12.7                  9.1                  11.1
# 4        Z                  12.1                  8.7                  10.6
#
#    FUELCONSUMPTION_COMB_MPG  CO2EMISSIONS
# 0                        33           196
# 1                        29           221
# 2                        48           136
# 3                        25           255
# 4                        27           244

# %%
df.select_dtypes('object')
# Out:
#        MAKE       MODEL    VEHICLECLASS TRANSMISSION FUELTYPE
# 0     ACURA         ILX         COMPACT          AS5        Z
# 1     ACURA         ILX         COMPACT           M6        Z
# 2     ACURA  ILX HYBRID         COMPACT          AV7        Z
# 3     ACURA     MDX 4WD     SUV - SMALL          AS6        Z
# 4     ACURA     RDX AWD     SUV - SMALL          AS6        Z
# ...     ...         ...             ...          ...      ...
# 1062  VOLVO    XC60 AWD     SUV - SMALL          AS6        X
# 1063  VOLVO    XC60 AWD     SUV - SMALL          AS6        X
# 1064  VOLVO    XC70 AWD     SUV - SMALL          AS6        X
# 1065  VOLVO    XC70 AWD     SUV - SMALL          AS6        X
# 1066  VOLVO    XC90 AWD  SUV - STANDARD          AS6        X
#
# [1067 rows x 5 columns]

# %%
df.select_dtypes('object').columns
# Out:
# Index(['MAKE', 'MODEL', 'VEHICLECLASS', 'TRANSMISSION', 'FUELTYPE'], dtype='object')

# %%
cat_cols = df.select_dtypes('object')

# %%
for col in cat_cols:
    count = df[col].value_counts()
    print(count)
    print("=======================")
# Out:
# FORD             90
# CHEVROLET        86
# BMW              64
# MERCEDES-BENZ    59
# TOYOTA           49
# GMC              49
# AUDI             49
# PORSCHE          44
# VOLKSWAGEN       42
# DODGE            39
# MINI             36
# NISSAN           33
# KIA              33
# CADILLAC         32
# JEEP             31
# MAZDA            27
# HYUNDAI          24
# SUBARU           23
# JAGUAR           22
# LEXUS            22
# HONDA            21
# INFINITI         21
# CHRYSLER         19
# LAND ROVER       19
# BUICK            16
# MITSUBISHI       16
# RAM              13
# ACURA            12
# VOLVO            11
# LINCOLN          11
# FIAT             10
# SCION             9
# BENTLEY           8
# ASTON MARTIN      7
# ROLLS-ROYCE       7
# MASERATI          6
# LAMBORGHINI       3
# SMART             2
# SRT               2
# Name: MAKE, dtype: int64
# =======================
# F150 FFV            8
# F150 FFV 4X4        8
# FOCUS FFV           6
# BEETLE              6
# ACCORD              6
#                    ..
# EQUUS               1
# SLS AMG ROADSTER    1
# 911 GT3             1
# CROSSTOUR AWD       1
# XJR LWB             1
# Name: MODEL, Length: 663, dtype: int64
# =======================
# MID-SIZE                    178
# COMPACT                     172
# SUV - SMALL                 154
# SUV - STANDARD              110
# FULL-SIZE                    86
# TWO-SEATER                   71
# SUBCOMPACT                   65
# PICKUP TRUCK - STANDARD      62
# MINICOMPACT                  47
# STATION WAGON - SMALL        36
# VAN - PASSENGER              25
# VAN - CARGO                  22
# MINIVAN                      14
# PICKUP TRUCK - SMALL         12
# SPECIAL PURPOSE VEHICLE       7
# STATION WAGON - MID-SIZE      6
# Name: VEHICLECLASS, dtype: int64
# =======================
# A6     222
# AS6    189
# M6     141
# A8      87
# AS8     80
# AS7     76
# M5      48
# AV      46
# A4      45
# AM7     34
# A5      30
# A7      12
# AV6     11
# AS5     10
# M7       9
# A9       8
# AM6      6
# AV7      5
# AV8      3
# AS9      2
# AM5      2
# AS4      1
# Name: TRANSMISSION, dtype: int64
# =======================
# X    514
# Z    434
# E     92
# D     27
# Name: FUELTYPE, dtype: int64
# =======================

# %%
df.drop(columns = cat_cols,inplace = True)

# %%
df
# Out:
#       ENGINESIZE  CYLINDERS  FUELCONSUMPTION_CITY  FUELCONSUMPTION_HWY  \
# 0            2.0          4                   9.9                  6.7
# 1            2.4          4                  11.2                  7.7
# 2            1.5          4                   6.0                  5.8
# 3            3.5          6                  12.7                  9.1
# 4            3.5          6                  12.1                  8.7
# ...          ...        ...                   ...                  ...
# 1062         3.0          6                  13.4                  9.8
# 1063         3.2          6                  13.2                  9.5
# 1064         3.0          6                  13.4                  9.8
# 1065         3.2          6                  12.9                  9.3
# 1066         3.2          6                  14.9                 10.2
#
#       FUELCONSUMPTION_COMB  FUELCONSUMPTION_COMB_MPG  CO2EMISSIONS
# 0                      8.5                        33           196
# 1                      9.6                        29           221
# 2                      5.9                        48           136
# 3                     11.1                        25           255
# 4                     10.6                        27           244
# ...                    ...                       ...           ...
# 1062                  11.8                        24           271
# 1063                  11.5                        25           264
# 1064                  11.8                        24           271
# 1065                  11.3                        25           260
# 1066                  12.8                        22           294
#
# [1067 rows x 7 columns]

# %%
sns.pairplot(df,hue='CYLINDERS')
# Out:
# C:\Users\User\anaconda3\lib\site-packages\seaborn\distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)

# %%
df.corr()
# Out:
#                           ENGINESIZE  CYLINDERS  FUELCONSUMPTION_CITY  \
# ENGINESIZE                  1.000000   0.934011              0.832225
# CYLINDERS                   0.934011   1.000000              0.796473
# FUELCONSUMPTION_CITY        0.832225   0.796473              1.000000
# FUELCONSUMPTION_HWY         0.778746   0.724594              0.965718
# FUELCONSUMPTION_COMB        0.819482   0.776788              0.995542
# FUELCONSUMPTION_COMB_MPG   -0.808554  -0.770430             -0.935613
# CO2EMISSIONS                0.874154   0.849685              0.898039
#
#                           FUELCONSUMPTION_HWY  FUELCONSUMPTION_COMB  \
# ENGINESIZE                           0.778746              0.819482
# CYLINDERS                            0.724594              0.776788
# FUELCONSUMPTION_CITY                 0.965718              0.995542
# FUELCONSUMPTION_HWY                  1.000000              0.985804
# FUELCONSUMPTION_COMB                 0.985804              1.000000
# FUELCONSUMPTION_COMB_MPG            -0.893809             -0.927965
# CO2EMISSIONS                         0.861748              0.892129
#
#                           FUELCONSUMPTION_COMB_MPG  CO2EMISSIONS
# ENGINESIZE                               -0.808554      0.874154
# CYLINDERS                                -0.770430      0.849685
# FUELCONSUMPTION_CITY                     -0.935613      0.898039
# FUELCONSUMPTION_HWY                      -0.893809      0.861748
# FUELCONSUMPTION_COMB                     -0.927965      0.892129
# FUELCONSUMPTION_COMB_MPG                  1.000000     -0.906394
# CO2EMISSIONS                             -0.906394      1.000000

# %%
df.corr()[['CO2EMISSIONS']]      #another process df.corr().CO2EMISSIONS
# Out:
#                           CO2EMISSIONS
# ENGINESIZE                    0.874154
# CYLINDERS                     0.849685
# FUELCONSUMPTION_CITY          0.898039
# FUELCONSUMPTION_HWY           0.861748
# FUELCONSUMPTION_COMB          0.892129
# FUELCONSUMPTION_COMB_MPG     -0.906394
# CO2EMISSIONS                  1.000000

# %%
df.corr()[['CO2EMISSIONS']].sort_values(by=['CO2EMISSIONS'],ascending=False)
# Out:
#                           CO2EMISSIONS
# CO2EMISSIONS                  1.000000
# FUELCONSUMPTION_CITY          0.898039
# FUELCONSUMPTION_COMB          0.892129
# ENGINESIZE                    0.874154
# FUELCONSUMPTION_HWY           0.861748
# CYLINDERS                     0.849685
# FUELCONSUMPTION_COMB_MPG     -0.906394

# %%
sns.heatmap(df.corr()[['CO2EMISSIONS']].sort_values(by=['CO2EMISSIONS'],ascending=False),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Outliers and Treatment

# %%
plt.figure(figsize=(10,7))
sns.set(style='darkgrid')
sns.boxplot(data = df[['FUELCONSUMPTION_CITY','FUELCONSUMPTION_COMB','ENGINESIZE']])
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(10,7))
sns.set(style='darkgrid')
sns.boxplot(data = df[['FUELCONSUMPTION_HWY','CYLINDERS','FUELCONSUMPTION_COMB_MPG']])
# Out:
# <AxesSubplot:>

# %%
q1,q3 = np.quantile(df.ENGINESIZE, .25),np.quantile(df.ENGINESIZE, .75)
q1,q3
# Out:
# (2.0, 4.3)

# %%
iqr = q3 - q1
iqr
# Out:
# 2.3

# %%
lower_outlier = np.where(df.ENGINESIZE < q1 - (1.5*iqr))[0]
lower_outlier
# Out:
# array([], dtype=int64)

# %%
upper_outlier = np.where(df.ENGINESIZE > q3 + (1.5*iqr))[0]
upper_outlier
# Out:
# array([940, 941], dtype=int64)

# %%
#df.drop(upper_outlier,inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1067 entries, 0 to 1066
# Data columns (total 7 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ENGINESIZE                1067 non-null   float64
#  1   CYLINDERS                 1067 non-null   int64
#  2   FUELCONSUMPTION_CITY      1067 non-null   float64
#  3   FUELCONSUMPTION_HWY       1067 non-null   float64
#  4   FUELCONSUMPTION_COMB      1067 non-null   float64
#  5   FUELCONSUMPTION_COMB_MPG  1067 non-null   int64
#  6   CO2EMISSIONS              1067 non-null   int64
# dtypes: float64(4), int64(3)
# memory usage: 58.5 KB

# %% [markdown]
# ### Test code for practice

# %%
Q1 = df['FUELCONSUMPTION_CITY'].quantile(0.25)
Q3 = df['FUELCONSUMPTION_CITY'].quantile(0.75)
Q1,Q3
# Out:
# (10.25, 15.55)

# %%
IQR = Q3 - Q1
IQR
# Out:
# 5.300000000000001

# %%
lower_limit = Q1- 1.5*IQR
upper_limit = Q3 + 1.5*IQR
lower_limit,upper_limit
# Out:
# (2.299999999999999, 23.5)

# %%
outlier = df[(df['FUELCONSUMPTION_CITY']<lower_limit) | (df['FUELCONSUMPTION_CITY']>upper_limit) ]
outlier
# Out:
#      ENGINESIZE  CYLINDERS  FUELCONSUMPTION_CITY  FUELCONSUMPTION_HWY  \
# 182         6.2          8                  25.7                 17.8
# 214         5.3          8                  23.7                 18.8
# 216         5.3          8                  23.9                 18.5
# 218         5.3          8                  25.3                 19.3
# 220         5.3          8                  23.9                 18.5
# 222         5.3          8                  25.3                 19.3
# 225         6.0          8                  30.0                 20.4
# 228         6.0          8                  30.2                 20.5
# 344         4.6          8                  24.1                 19.2
# 346         5.4          8                  24.9                 19.6
# 348         4.6          8                  25.5                 20.0
# 349         6.8         10                  23.9                 17.8
# 351         5.4          8                  26.7                 20.5
# 362         5.4          8                  24.5                 18.0
# 438         5.3          8                  23.7                 18.8
# 440         5.3          8                  23.9                 18.5
# 442         5.3          8                  25.3                 19.3
# 444         5.3          8                  23.9                 18.5
# 446         5.3          8                  25.3                 19.3
# 449         6.0          8                  30.0                 20.4
# 452         6.0          8                  30.2                 20.5
# 476         6.2          8                  25.7                 17.8
# 642         5.0          8                  25.0                 16.9
# 648         5.0          8                  24.0                 16.6
# 654         5.0          8                  25.0                 16.9
# 687         5.4          8                  24.5                 18.0
#
#      FUELCONSUMPTION_COMB  FUELCONSUMPTION_COMB_MPG  CO2EMISSIONS
# 182                  22.1                        13           354
# 214                  21.5                        13           344
# 216                  21.5                        13           344
# 218                  22.6                        12           362
# 220                  21.5                        13           344
# 222                  22.6                        12           362
# 225                  25.7                        11           411
# 228                  25.8                        11           413
# 344                  21.9                        13           350
# 346                  22.5                        13           360
# 348                  23.0                        12           368
# 349                  21.2                        13           488
# 351                  23.9                        12           382
# 362                  21.6                        13           346
# 438                  21.5                        13           344
# 440                  21.5                        13           344
# 442                  22.6                        12           362
# 444                  21.5                        13           344
# 446                  22.6                        12           362
# 449                  25.7                        11           411
# 452                  25.8                        11           413
# 476                  22.1                        13           354
# 642                  21.4                        13           342
# 648                  20.7                        14           331
# 654                  21.4                        13           342
# 687                  21.6                        13           346

# %%
df[(df['FUELCONSUMPTION_CITY']<lower_limit) | (df['FUELCONSUMPTION_CITY']>upper_limit)].shape
# Out:
# (26, 7)

# %%
no_outlier = df[(df['FUELCONSUMPTION_CITY'] > lower_limit) & (df['FUELCONSUMPTION_CITY'] < upper_limit)]
no_outlier
# Out:
#       ENGINESIZE  CYLINDERS  FUELCONSUMPTION_CITY  FUELCONSUMPTION_HWY  \
# 0            2.0          4                   9.9                  6.7
# 1            2.4          4                  11.2                  7.7
# 2            1.5          4                   6.0                  5.8
# 3            3.5          6                  12.7                  9.1
# 4            3.5          6                  12.1                  8.7
# ...          ...        ...                   ...                  ...
# 1062         3.0          6                  13.4                  9.8
# 1063         3.2          6                  13.2                  9.5
# 1064         3.0          6                  13.4                  9.8
# 1065         3.2          6                  12.9                  9.3
# 1066         3.2          6                  14.9                 10.2
#
#       FUELCONSUMPTION_COMB  FUELCONSUMPTION_COMB_MPG  CO2EMISSIONS
# 0                      8.5                        33           196
# 1                      9.6                        29           221
# 2                      5.9                        48           136
# 3                     11.1                        25           255
# 4                     10.6                        27           244
# ...                    ...                       ...           ...
# 1062                  11.8                        24           271
# 1063                  11.5                        25           264
# 1064                  11.8                        24           271
# 1065                  11.3                        25           260
# 1066                  12.8                        22           294
#
# [1039 rows x 7 columns]

# %%
no_outlier.shape
# Out:
# (1039, 7)

# %% [markdown]
# ### No outlier taking

# %%
df = no_outlier
df
# Out:
#       ENGINESIZE  CYLINDERS  FUELCONSUMPTION_CITY  FUELCONSUMPTION_HWY  \
# 0            2.0          4                   9.9                  6.7
# 1            2.4          4                  11.2                  7.7
# 2            1.5          4                   6.0                  5.8
# 3            3.5          6                  12.7                  9.1
# 4            3.5          6                  12.1                  8.7
# ...          ...        ...                   ...                  ...
# 1062         3.0          6                  13.4                  9.8
# 1063         3.2          6                  13.2                  9.5
# 1064         3.0          6                  13.4                  9.8
# 1065         3.2          6                  12.9                  9.3
# 1066         3.2          6                  14.9                 10.2
#
#       FUELCONSUMPTION_COMB  FUELCONSUMPTION_COMB_MPG  CO2EMISSIONS
# 0                      8.5                        33           196
# 1                      9.6                        29           221
# 2                      5.9                        48           136
# 3                     11.1                        25           255
# 4                     10.6                        27           244
# ...                    ...                       ...           ...
# 1062                  11.8                        24           271
# 1063                  11.5                        25           264
# 1064                  11.8                        24           271
# 1065                  11.3                        25           260
# 1066                  12.8                        22           294
#
# [1039 rows x 7 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1039 entries, 0 to 1066
# Data columns (total 7 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ENGINESIZE                1039 non-null   float64
#  1   CYLINDERS                 1039 non-null   int64
#  2   FUELCONSUMPTION_CITY      1039 non-null   float64
#  3   FUELCONSUMPTION_HWY       1039 non-null   float64
#  4   FUELCONSUMPTION_COMB      1039 non-null   float64
#  5   FUELCONSUMPTION_COMB_MPG  1039 non-null   int64
#  6   CO2EMISSIONS              1039 non-null   int64
# dtypes: float64(4), int64(3)
# memory usage: 64.9 KB

# %% [markdown]
# # Outlier Detection and Removal OOP

# %%
class OutlierTreatment:
    
    def __init__(self, data):
        self.data = data
        
    def getInfo(self):
        return (self.data.shape)
    
    def outlier(self):
        Q1 = self.data.quantile(0.25)
        Q3 = self.data.quantile(0.75)
        IQR = Q3 - Q1
        lower_limit = Q1 - 1.5*IQR
        upper_limit = Q3 + 1.5*IQR
        return lower_limit, upper_limit
        
    def count_outlier(self, dfa):
        self.lower_limit, self.upper_limit = self.outlier()
        Total_outlier = len(dfa[(self.data <= self.lower_limit)|(self.data >= self.upper_limit)])
        return Total_outlier
    
    def clean_outlier(self, dfa):
        self.lower_limit, self.upper_limit = self.outlier()
        dfx = dfa[(self.data>self.lower_limit)&(self.data<self.upper_limit)]
        return dfx

# %%
# ruuning function to each column multiple time until any outlier left
columnslist = ['FUELCONSUMPTION_CITY','FUELCONSUMPTION_HWY','FUELCONSUMPTION_COMB','ENGINESIZE','FUELCONSUMPTION_HWY','CYLINDERS','FUELCONSUMPTION_COMB_MPG']
for i in columnslist:
    while True:
        d = OutlierTreatment(df[i])
        d.getInfo()
        d.outlier()
        d.count_outlier(df)
        if d.count_outlier(df) == 0:
            break
        df = d.clean_outlier(df)
df.shape
# Out:
# (974, 7)

# %%
plt.figure(figsize=(20,16))
sns.set(style='darkgrid')
sns.boxplot(data = df[['FUELCONSUMPTION_CITY','FUELCONSUMPTION_COMB','ENGINESIZE','FUELCONSUMPTION_HWY','CYLINDERS','FUELCONSUMPTION_COMB_MPG']])
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Dataset Split

# %%
x = df.drop(columns = ['CO2EMISSIONS'])
y = df['CO2EMISSIONS']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.20,random_state=33)

# %%
x_train
# Out:
#      ENGINESIZE  CYLINDERS  FUELCONSUMPTION_CITY  FUELCONSUMPTION_HWY  \
# 171         3.0          6                  12.8                  9.1
# 795         1.6          4                   9.1                  6.7
# 260         1.2          4                   7.6                  6.0
# 281         3.6          6                  12.5                  8.1
# 86          3.0          6                  11.4                  7.3
# ..          ...        ...                   ...                  ...
# 732         4.7          8                  15.4                 10.4
# 644         3.0          6                  14.2                 10.2
# 804         1.6          4                   9.3                  7.0
# 437         5.3          8                  18.3                 14.2
# 24          2.0          4                  10.8                  7.5
#
#      FUELCONSUMPTION_COMB  FUELCONSUMPTION_COMB_MPG
# 171                  11.1                        25
# 795                   8.0                        35
# 260                   6.9                        41
# 281                  10.5                        27
# 86                    9.6                        29
# ..                    ...                       ...
# 732                  13.2                        21
# 644                  12.4                        23
# 804                   8.3                        34
# 437                  16.5                        17
# 24                    9.3                        30
#
# [779 rows x 6 columns]

# %%
x_test
# Out:
#       ENGINESIZE  CYLINDERS  FUELCONSUMPTION_CITY  FUELCONSUMPTION_HWY  \
# 174          6.2          8                  16.7                 12.5
# 376          3.7          6                  18.8                 13.7
# 166          2.0          4                  12.6                  8.5
# 636          2.0          4                  13.5                  9.9
# 920          3.6          6                  13.3                  9.1
# ...          ...        ...                   ...                  ...
# 78           2.0          4                  10.2                  7.0
# 1057         2.5          5                  11.6                  8.3
# 570          3.2          6                  12.3                  8.3
# 234          2.5          4                   9.3                  6.4
# 796          1.6          4                  10.0                  7.8
#
#       FUELCONSUMPTION_COMB  FUELCONSUMPTION_COMB_MPG
# 174                   14.8                        19
# 376                   16.5                        17
# 166                   10.8                        26
# 636                   11.9                        24
# 920                   11.4                        25
# ...                    ...                       ...
# 78                     8.8                        32
# 1057                  10.1                        28
# 570                   10.5                        27
# 234                    8.0                        35
# 796                    9.0                        31
#
# [195 rows x 6 columns]

# %% [markdown]
# # Fearure Engineering and Selection

# %%
from sklearn.feature_selection import mutual_info_regression

# %%
scores = mutual_info_regression(x_train,y_train,random_state=33)
scores = pd.DataFrame(scores)
scores.index = x_train.columns
scores.sort_values(by=0,ascending=False)
# Out:
#                                  0
# FUELCONSUMPTION_COMB      4.088892
# FUELCONSUMPTION_COMB_MPG  2.908952
# FUELCONSUMPTION_CITY      2.138975
# FUELCONSUMPTION_HWY       1.587947
# ENGINESIZE                0.982349
# CYLINDERS                 0.651813

# %% [markdown]
# # Modeling Simple LinearRegression

# %% [markdown]
# ### Model building ON FUELCONSUMPTION_COMB

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
model.fit(x_train[['FUELCONSUMPTION_COMB']],y_train)
# Out:
# LinearRegression()

# %%
model.predict(x_train[['FUELCONSUMPTION_COMB']])
# Out:
# array([249.89422707, 192.94090503, 172.73166172, 238.87100345,
#        222.33616802, 288.47550975, 213.15014834, 279.28949007,
#        279.28949007, 281.126694  , 187.42929322, 214.98735227,
#        268.26626644, 189.26649716, 220.49896408, 323.38238455,
#        339.91721998, 213.15014834, 192.94090503, 259.08024676,
#        249.89422707, 198.45251684, 314.19636487, 281.126694  ,
#        259.08024676, 282.96389794, 238.87100345, 349.10323967,
#        216.82455621, 297.66152943, 211.3129444 , 279.28949007,
#        330.7312003 , 191.10370109, 231.52218771, 181.91768141,
#        286.63830581, 235.19659558, 211.3129444 , 226.01057589,
#        194.77810897, 203.96412865, 332.56840424, 185.59208928,
#        244.38261526, 268.26626644, 259.08024676, 323.38238455,
#        192.94090503, 205.80133259, 328.89399636, 214.98735227,
#        249.89422707, 222.33616802, 288.47550975, 213.15014834,
#        367.47527904, 226.01057589, 194.77810897, 167.22004991,
#        170.89445779, 227.84777983, 178.24327354, 205.80133259,
#        246.2198192 , 198.45251684, 275.61508219, 301.33593731,
#        218.66176015, 308.68475306, 226.01057589, 255.40583889,
#        200.28972078, 185.59208928, 211.3129444 , 233.35939164,
#        227.84777983, 270.10347038, 203.96412865, 248.05702314,
#        255.40583889, 301.33593731, 316.0335688 , 292.14991762,
#        238.87100345, 226.01057589, 233.35939164, 189.26649716,
#        192.94090503, 222.33616802, 282.96389794, 354.61485148,
#        255.40583889, 349.10323967, 281.126694  , 286.63830581,
#        226.01057589, 229.68498377, 189.26649716, 282.96389794,
#        268.26626644, 281.126694  , 213.15014834, 343.59162786,
#        198.45251684, 316.0335688 , 248.05702314, 194.77810897,
#        264.59185857, 332.56840424, 235.19659558, 251.73143101,
#        246.2198192 , 242.54541133, 189.26649716, 317.87077274,
#        205.80133259, 227.84777983, 354.61485148, 339.91721998,
#        240.70820739, 279.28949007, 213.15014834, 248.05702314,
#        229.68498377, 203.96412865, 312.35916093, 240.70820739,
#        213.15014834, 271.94067432, 282.96389794, 222.33616802,
#        338.08001605, 251.73143101, 183.75488535, 384.01011447,
#        207.63853653, 246.2198192 , 202.12692472, 244.38261526,
#        378.49850266, 299.49873337, 180.08047747, 279.28949007,
#        244.38261526, 262.75465463, 233.35939164, 321.54518061,
#        238.87100345, 259.08024676, 240.70820739, 216.82455621,
#        281.126694  , 277.45228613, 271.94067432, 292.14991762,
#        207.63853653, 213.15014834, 235.19659558, 279.28949007,
#        286.63830581, 224.17337196, 211.3129444 , 257.24304282,
#        349.10323967, 262.75465463, 275.61508219, 196.6153129 ,
#        260.9174507 , 224.17337196, 200.28972078, 200.28972078,
#        246.2198192 , 266.42906251, 220.49896408, 262.75465463,
#        192.94090503, 303.17314125, 279.28949007, 349.10323967,
#        235.19659558, 380.3357066 , 288.47550975, 273.77787825,
#        198.45251684, 349.10323967, 216.82455621])

# %%
y_train
# Out:
# 171    255
# 795    184
# 260    159
# 281    242
# 86     221
#       ...
# 732    304
# 644    285
# 804    191
# 437    380
# 24     214
# Name: CO2EMISSIONS, Length: 779, dtype: int64

# %%
model.coef_
# Out:
# array([18.37203937])

# %%
model.intercept_
# Out:
# 45.964590077556835

# %% [markdown]
# # Evaluation

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %%
y_pred_train = model.predict(x_train[['FUELCONSUMPTION_COMB']])
y_pred_test = model.predict(x_test[['FUELCONSUMPTION_COMB']])

# %%
mean_absolute_error(y_true = y_train,y_pred = y_pred_train)
# Out:
# 14.102589702601213

# %%
mean_absolute_error(y_true = y_test,y_pred = y_pred_test)
# Out:
# 13.47708048533153

# %%
mean_squared_error(y_true = y_train,y_pred = y_pred_train)
# Out:
# 549.1554015695712

# %%
mean_squared_error(y_true = y_test,y_pred = y_pred_test)
# Out:
# 512.6441137533545

# %%
r2_score(y_true = y_train,y_pred = y_pred_train), r2_score(y_true = y_test,y_pred = y_pred_test)
# Out:
# (0.8195348402986343, 0.8168120536831087)

# %%
print("mean_absolute_error on train set: ",mean_absolute_error(y_true = y_train,y_pred = y_pred_train))
print("mean_absolute_error on test set: ",mean_absolute_error(y_true = y_test,y_pred = y_pred_test))
print(" ")

print("mean_squared_error on train set: ",mean_squared_error(y_true = y_train,y_pred = y_pred_train))
print("mean_squared_error on test set: ",mean_squared_error(y_true = y_test,y_pred = y_pred_test))
print(" ")

print("r2_score on train set: ",r2_score(y_true = y_train,y_pred = y_pred_train))
print("r2_score on test set: ",r2_score(y_true = y_test,y_pred = y_pred_test))
# Out:
# mean_absolute_error on train set:  14.102589702601213
# mean_absolute_error on test set:  13.47708048533153
#
# mean_squared_error on train set:  549.1554015695712
# mean_squared_error on test set:  512.6441137533545
#
# r2_score on train set:  0.8195348402986343
# r2_score on test set:  0.8168120536831087

# %% [markdown]
# # Model Visualization

# %% [markdown]
# ### ON FUELCONSUMPTION_COMB

# %%
x_train[['FUELCONSUMPTION_COMB']].describe().T
# Out:
#                       count       mean       std  min  25%   50%   75%   max
# FUELCONSUMPTION_COMB  779.0  11.057895  2.719921  6.4  8.9  10.6  12.7  18.4

# %%
dummy_x = np.linspace(6.2,19,200)
dummy_x = dummy_x.reshape(-1,1) # -1 = row , 1 = columns
dummy_x
# Out:
# array([[ 6.2       ],
#        [ 6.26432161],
#        [ 6.32864322],
#        [ 6.39296482],
#        [ 6.45728643],
#        [ 6.52160804],
#        [ 6.58592965],
#        [ 6.65025126],
#        [ 6.71457286],
#        [ 6.77889447],
#        [ 6.84321608],
#        [ 6.90753769],
#        [ 6.9718593 ],
#        [ 7.0361809 ],
#        [ 7.10050251],
#        [ 7.16482412],
#        [ 7.22914573],
#        [ 7.29346734],
#        [ 7.35778894],
#        [ 7.42211055],
#        [ 7.48643216],
#        [ 7.55075377],
#        [ 7.61507538],
#        [ 7.67939698],
#        [ 7.74371859],
#        [ 7.8080402 ],
#        [ 7.87236181],
#        [ 7.93668342],
#        [ 8.00100503],
#        [ 8.06532663],
#        [ 8.12964824],
#        [ 8.19396985],
#        [ 8.25829146],
#        [ 8.32261307],
#        [ 8.38693467],
#        [ 8.45125628],
#        [ 8.51557789],
#        [ 8.5798995 ],
#        [ 8.64422111],
#        [ 8.70854271],
#        [ 8.77286432],
#        [ 8.83718593],
#        [ 8.90150754],
#        [ 8.96582915],
#        [ 9.03015075],
#        [ 9.09447236],
#        [ 9.15879397],
#        [ 9.22311558],
#        [ 9.28743719],
#        [ 9.35175879],
#        [ 9.4160804 ],
#        [ 9.48040201],
#        [ 9.54472362],
#        [ 9.60904523],
#        [ 9.67336683],
#        [ 9.73768844],
#        [ 9.80201005],
#        [ 9.86633166],
#        [ 9.93065327],
#        [ 9.99497487],
#        [10.05929648],
#        [10.12361809],
#        [10.1879397 ],
#        [10.25226131],
#        [10.31658291],
#        [10.38090452],
#        [10.44522613],
#        [10.50954774],
#        [10.57386935],
#        [10.63819095],
#        [10.70251256],
#        [10.76683417],
#        [10.83115578],
#        [10.89547739],
#        [10.95979899],
#        [11.0241206 ],
#        [11.08844221],
#        [11.15276382],
#        [11.21708543],
#        [11.28140704],
#        [11.34572864],
#        [11.41005025],
#        [11.47437186],
#        [11.53869347],
#        [11.60301508],
#        [11.66733668],
#        [11.73165829],
#        [11.7959799 ],
#        [11.86030151],
#        [11.92462312],
#        [11.98894472],
#        [12.05326633],
#        [12.11758794],
#        [12.18190955],
#        [12.24623116],
#        [12.31055276],
#        [12.37487437],
#        [12.43919598],
#        [12.50351759],
#        [12.5678392 ],
#        [12.6321608 ],
#        [12.69648241],
#        [12.76080402],
#        [12.82512563],
#        [12.88944724],
#        [12.95376884],
#        [13.01809045],
#        [13.08241206],
#        [13.14673367],
#        [13.21105528],
#        [13.27537688],
#        [13.33969849],
#        [13.4040201 ],
#        [13.46834171],
#        [13.53266332],
#        [13.59698492],
#        [13.66130653],
#        [13.72562814],
#        [13.78994975],
#        [13.85427136],
#        [13.91859296],
#        [13.98291457],
#        [14.04723618],
#        [14.11155779],
#        [14.1758794 ],
#        [14.24020101],
#        [14.30452261],
#        [14.36884422],
#        [14.43316583],
#        [14.49748744],
#        [14.56180905],
#        [14.62613065],
#        [14.69045226],
#        [14.75477387],
#        [14.81909548],
#        [14.88341709],
#        [14.94773869],
#        [15.0120603 ],
#        [15.07638191],
#        [15.14070352],
#        [15.20502513],
#        [15.26934673],
#        [15.33366834],
#        [15.39798995],
#        [15.46231156],
#        [15.52663317],
#        [15.59095477],
#        [15.65527638],
#        [15.71959799],
#        [15.7839196 ],
#        [15.84824121],
#        [15.91256281],
#        [15.97688442],
#        [16.04120603],
#        [16.10552764],
#        [16.16984925],
#        [16.23417085],
#        [16.29849246],
#        [16.36281407],
#        [16.42713568],
#        [16.49145729],
#        [16.55577889],
#        [16.6201005 ],
#        [16.68442211],
#        [16.74874372],
#        [16.81306533],
#        [16.87738693],
#        [16.94170854],
#        [17.00603015],
#        [17.07035176],
#        [17.13467337],
#        [17.19899497],
#        [17.26331658],
#        [17.32763819],
#        [17.3919598 ],
#        [17.45628141],
#        [17.52060302],
#        [17.58492462],
#        [17.64924623],
#        [17.71356784],
#        [17.77788945],
#        [17.84221106],
#        [17.90653266],
#        [17.97085427],
#        [18.03517588],
#        [18.09949749],
#        [18.1638191 ],
#        [18.2281407 ],
#        [18.29246231],
#        [18.35678392],
#        [18.42110553],
#        [18.48542714],
#        [18.54974874],
#        [18.61407035],
#        [18.67839196],
#        [18.74271357],
#        [18.80703518],
#        [18.87135678],
#        [18.93567839],
#        [19.        ]])

# %%
ypred = model.predict(dummy_x)

# %%
plt.figure(figsize=(10,7))
plt.scatter (x_train[['FUELCONSUMPTION_COMB']],y_train,label='Actual')
plt.plot(dummy_x, ypred, label='Regression Line', color='darkorange', linewidth=5) # line plot
plt.xlabel("FUELCONSUMPTION_COMB")
plt.ylabel("CO2EMISSIONS")
plt.legend()
plt.show()

# %% [markdown]
# # Visualization By OOP

# %% [markdown]
# ### Main OOP Code

# %%
class visualization:
    def __init__(self,give_x_train,give_y_train,give_dummy_x,give_ypred,give_xlabel):
        self.give_x_train = give_x_train
        self.give_y_train = give_y_train
        self.give_dummy_x = give_dummy_x
        self.give_ypred = ypred
        self.give_xlabel = give_xlabel
        
    def visualize(self):
        plt.figure(figsize=(10,7))
        plt.scatter (self.give_x_train, self.give_y_train,label='Actual')
        plt.plot(self.give_dummy_x, self.give_ypred, label='Regression Line', color='darkorange', linewidth=5) # line plot
        plt.xlabel(self.give_xlabel)
        plt.ylabel("CO2EMISSIONS")
        plt.legend()
        plt.show()

# %% [markdown]
# ### ON FUELCONSUMPTION_COMB

# %%
model.fit(x_train[['FUELCONSUMPTION_COMB']],y_train)
model.predict(x_train[['FUELCONSUMPTION_COMB']])

print("mean_absolute_error on train set: ",mean_absolute_error(y_true = y_train,y_pred = y_pred_train))
print("mean_absolute_error on test set: ",mean_absolute_error(y_true = y_test,y_pred = y_pred_test))
print(" ")

print("mean_squared_error on train set: ",mean_squared_error(y_true = y_train,y_pred = y_pred_train))
print("mean_squared_error on test set: ",mean_squared_error(y_true = y_test,y_pred = y_pred_test))
print(" ")

print("r2_score on train set: ",r2_score(y_true = y_train,y_pred = y_pred_train))
print("r2_score on test set: ",r2_score(y_true = y_test,y_pred = y_pred_test))
# Out:
# mean_absolute_error on train set:  14.102589702601213
# mean_absolute_error on test set:  13.47708048533153
#
# mean_squared_error on train set:  549.1554015695712
# mean_squared_error on test set:  512.6441137533545
#
# r2_score on train set:  0.8195348402986343
# r2_score on test set:  0.8168120536831087

# %%
x_train[['FUELCONSUMPTION_COMB']].describe().T
# Out:
#                       count       mean       std  min  25%   50%   75%   max
# FUELCONSUMPTION_COMB  779.0  11.057895  2.719921  6.4  8.9  10.6  12.7  18.4

# %%
dummy_x = np.linspace(6.2,19,200)
dummy_x = dummy_x.reshape(-1,1) # -1 = row , 1 = columns
dummy_x
# Out:
# array([[ 6.2       ],
#        [ 6.26432161],
#        [ 6.32864322],
#        [ 6.39296482],
#        [ 6.45728643],
#        [ 6.52160804],
#        [ 6.58592965],
#        [ 6.65025126],
#        [ 6.71457286],
#        [ 6.77889447],
#        [ 6.84321608],
#        [ 6.90753769],
#        [ 6.9718593 ],
#        [ 7.0361809 ],
#        [ 7.10050251],
#        [ 7.16482412],
#        [ 7.22914573],
#        [ 7.29346734],
#        [ 7.35778894],
#        [ 7.42211055],
#        [ 7.48643216],
#        [ 7.55075377],
#        [ 7.61507538],
#        [ 7.67939698],
#        [ 7.74371859],
#        [ 7.8080402 ],
#        [ 7.87236181],
#        [ 7.93668342],
#        [ 8.00100503],
#        [ 8.06532663],
#        [ 8.12964824],
#        [ 8.19396985],
#        [17.3919598 ],
#        [17.45628141],
#        [17.52060302],
#        [17.58492462],
#        [17.64924623],
#        [17.71356784],
#        [17.77788945],
#        [17.84221106],
#        [17.90653266],
#        [17.97085427],
#        [18.03517588],
#        [18.09949749],
#        [18.1638191 ],
#        [18.2281407 ],
#        [18.29246231],
#        [18.35678392],
#        [18.42110553],
#        [18.48542714],
#        [18.54974874],
#        [18.61407035],
#        [18.67839196],
#        [18.74271357],
#        [18.80703518],
#        [18.87135678],
#        [18.93567839],
#        [19.        ]])

# %%
ypred = model.predict(dummy_x)

# %%
raihan = visualization(x_train[['FUELCONSUMPTION_COMB']],y_train,dummy_x,ypred,"FUELCONSUMPTION_COMB")
raihan.visualize()

# %% [markdown]
# ### ON ENGINESIZE

# %%
model = LinearRegression()
model.fit(x_train[['ENGINESIZE']],y_train)
model.predict(x_train[['ENGINESIZE']])

y_pred_train = model.predict(x_train[['ENGINESIZE']])
y_pred_test = model.predict(x_test[['ENGINESIZE']])

print("mean_absolute_error on train set: ",mean_absolute_error(y_true = y_train,y_pred = y_pred_train))
print("mean_absolute_error on test set: ",mean_absolute_error(y_true = y_test,y_pred = y_pred_test))
print(" ")

print("mean_squared_error on train set: ",mean_squared_error(y_true = y_train,y_pred = y_pred_train))
print("mean_squared_error on test set: ",mean_squared_error(y_true = y_test,y_pred = y_pred_test))
print(" ")

print("r2_score on train set: ",r2_score(y_true = y_train,y_pred = y_pred_train))
print("r2_score on test set: ",r2_score(y_true = y_test,y_pred = y_pred_test))
# Out:
# mean_absolute_error on train set:  21.909698517755036
# mean_absolute_error on test set:  20.788468048052867
#
# mean_squared_error on train set:  813.8568409413341
# mean_squared_error on test set:  777.3010047218788
#
# r2_score on train set:  0.7325478282563704
# r2_score on test set:  0.7222397158088399

# %%
x_train[['ENGINESIZE']].describe().T
# Out:
#             count    mean       std  min  25%  50%  75%  max
# ENGINESIZE  779.0  3.1819  1.295372  1.0  2.0  3.0  3.8  6.4

# %%
dummy_x = np.linspace(1, 7, 200)
dummy_x = dummy_x.reshape(-1,1) # -1 = row , 1 = columns
dummy_x
# Out:
# array([[1.        ],
#        [1.03015075],
#        [1.06030151],
#        [1.09045226],
#        [1.12060302],
#        [1.15075377],
#        [1.18090452],
#        [1.21105528],
#        [1.24120603],
#        [1.27135678],
#        [1.30150754],
#        [1.33165829],
#        [1.36180905],
#        [1.3919598 ],
#        [1.42211055],
#        [1.45226131],
#        [1.48241206],
#        [1.51256281],
#        [1.54271357],
#        [1.57286432],
#        [1.60301508],
#        [1.63316583],
#        [1.66331658],
#        [1.69346734],
#        [1.72361809],
#        [1.75376884],
#        [1.7839196 ],
#        [1.81407035],
#        [1.84422111],
#        [1.87437186],
#        [1.90452261],
#        [1.93467337],
#        [1.96482412],
#        [1.99497487],
#        [2.02512563],
#        [2.05527638],
#        [2.08542714],
#        [2.11557789],
#        [2.14572864],
#        [2.1758794 ],
#        [2.20603015],
#        [2.2361809 ],
#        [2.26633166],
#        [2.29648241],
#        [2.32663317],
#        [2.35678392],
#        [2.38693467],
#        [2.41708543],
#        [2.44723618],
#        [2.47738693],
#        [2.50753769],
#        [2.53768844],
#        [2.5678392 ],
#        [2.59798995],
#        [2.6281407 ],
#        [2.65829146],
#        [2.68844221],
#        [2.71859296],
#        [2.74874372],
#        [2.77889447],
#        [2.80904523],
#        [2.83919598],
#        [2.86934673],
#        [2.89949749],
#        [2.92964824],
#        [2.95979899],
#        [2.98994975],
#        [3.0201005 ],
#        [3.05025126],
#        [3.08040201],
#        [3.11055276],
#        [3.14070352],
#        [3.17085427],
#        [3.20100503],
#        [3.23115578],
#        [3.26130653],
#        [3.29145729],
#        [3.32160804],
#        [3.35175879],
#        [3.38190955],
#        [3.4120603 ],
#        [3.44221106],
#        [3.47236181],
#        [3.50251256],
#        [3.53266332],
#        [3.56281407],
#        [3.59296482],
#        [3.62311558],
#        [3.65326633],
#        [3.68341709],
#        [3.71356784],
#        [3.74371859],
#        [3.77386935],
#        [3.8040201 ],
#        [3.83417085],
#        [3.86432161],
#        [3.89447236],
#        [3.92462312],
#        [3.95477387],
#        [3.98492462],
#        [4.01507538],
#        [4.04522613],
#        [4.07537688],
#        [4.10552764],
#        [4.13567839],
#        [4.16582915],
#        [4.1959799 ],
#        [4.22613065],
#        [4.25628141],
#        [4.28643216],
#        [4.31658291],
#        [4.34673367],
#        [4.37688442],
#        [4.40703518],
#        [4.43718593],
#        [4.46733668],
#        [4.49748744],
#        [4.52763819],
#        [4.55778894],
#        [4.5879397 ],
#        [4.61809045],
#        [4.64824121],
#        [4.67839196],
#        [4.70854271],
#        [4.73869347],
#        [4.76884422],
#        [4.79899497],
#        [4.82914573],
#        [4.85929648],
#        [4.88944724],
#        [4.91959799],
#        [4.94974874],
#        [4.9798995 ],
#        [5.01005025],
#        [5.04020101],
#        [5.07035176],
#        [5.10050251],
#        [5.13065327],
#        [5.16080402],
#        [5.19095477],
#        [5.22110553],
#        [5.25125628],
#        [5.28140704],
#        [5.31155779],
#        [5.34170854],
#        [5.3718593 ],
#        [5.40201005],
#        [5.4321608 ],
#        [5.46231156],
#        [5.49246231],
#        [5.52261307],
#        [5.55276382],
#        [5.58291457],
#        [5.61306533],
#        [5.64321608],
#        [5.67336683],
#        [5.70351759],
#        [5.73366834],
#        [5.7638191 ],
#        [5.79396985],
#        [5.8241206 ],
#        [5.85427136],
#        [5.88442211],
#        [5.91457286],
#        [5.94472362],
#        [5.97487437],
#        [6.00502513],
#        [6.03517588],
#        [6.06532663],
#        [6.09547739],
#        [6.12562814],
#        [6.15577889],
#        [6.18592965],
#        [6.2160804 ],
#        [6.24623116],
#        [6.27638191],
#        [6.30653266],
#        [6.33668342],
#        [6.36683417],
#        [6.39698492],
#        [6.42713568],
#        [6.45728643],
#        [6.48743719],
#        [6.51758794],
#        [6.54773869],
#        [6.57788945],
#        [6.6080402 ],
#        [6.63819095],
#        [6.66834171],
#        [6.69849246],
#        [6.72864322],
#        [6.75879397],
#        [6.78894472],
#        [6.81909548],
#        [6.84924623],
#        [6.87939698],
#        [6.90954774],
#        [6.93969849],
#        [6.96984925],
#        [7.        ]])

# %%
ypred = model.predict(dummy_x)

# %%
raihan = visualization(x_train[['ENGINESIZE']],y_train,dummy_x,ypred,"ENGINESIZE")
raihan.visualize()

# %% [markdown]
# ### ON CYLINDERS

# %%
model = LinearRegression()
model.fit(x_train[['CYLINDERS']],y_train)
model.predict(x_train[['CYLINDERS']])

y_pred_train = model.predict(x_train[['CYLINDERS']])
y_pred_test = model.predict(x_test[['CYLINDERS']])

print("mean_absolute_error on train set: ",mean_absolute_error(y_true = y_train,y_pred = y_pred_train))
print("mean_absolute_error on test set: ",mean_absolute_error(y_true = y_test,y_pred = y_pred_test))
print(" ")

print("mean_squared_error on train set: ",mean_squared_error(y_true = y_train,y_pred = y_pred_train))
print("mean_squared_error on test set: ",mean_squared_error(y_true = y_test,y_pred = y_pred_test))
print(" ")

print("r2_score on train set: ",r2_score(y_true = y_train,y_pred = y_pred_train))
print("r2_score on test set: ",r2_score(y_true = y_test,y_pred = y_pred_test))
# Out:
# mean_absolute_error on train set:  23.202945346731934
# mean_absolute_error on test set:  23.142746751348348
#
# mean_squared_error on train set:  863.7845317290521
# mean_squared_error on test set:  884.5077679284407
#
# r2_score on train set:  0.7161404348923548
# r2_score on test set:  0.6839305140522777

# %%
x_train[['CYLINDERS']].describe().T
# Out:
#            count      mean       std  min  25%  50%  75%  max
# CYLINDERS  779.0  5.573813  1.557182  3.0  4.0  6.0  6.0  8.0

# %%
dummy_x = np.linspace(3, 8, 200)
dummy_x = dummy_x.reshape(-1,1) # -1 = row , 1 = columns
dummy_x
# Out:
# array([[3.        ],
#        [3.02512563],
#        [3.05025126],
#        [3.07537688],
#        [3.10050251],
#        [3.12562814],
#        [3.15075377],
#        [3.1758794 ],
#        [3.20100503],
#        [3.22613065],
#        [3.25125628],
#        [3.27638191],
#        [3.30150754],
#        [3.32663317],
#        [3.35175879],
#        [3.37688442],
#        [3.40201005],
#        [3.42713568],
#        [3.45226131],
#        [3.47738693],
#        [3.50251256],
#        [3.52763819],
#        [3.55276382],
#        [3.57788945],
#        [3.60301508],
#        [3.6281407 ],
#        [3.65326633],
#        [3.67839196],
#        [3.70351759],
#        [3.72864322],
#        [3.75376884],
#        [3.77889447],
#        [3.8040201 ],
#        [3.82914573],
#        [3.85427136],
#        [3.87939698],
#        [3.90452261],
#        [3.92964824],
#        [3.95477387],
#        [3.9798995 ],
#        [4.00502513],
#        [4.03015075],
#        [4.05527638],
#        [4.08040201],
#        [4.10552764],
#        [4.13065327],
#        [4.15577889],
#        [4.18090452],
#        [4.20603015],
#        [4.23115578],
#        [4.25628141],
#        [4.28140704],
#        [4.30653266],
#        [4.33165829],
#        [4.35678392],
#        [4.38190955],
#        [4.40703518],
#        [4.4321608 ],
#        [4.45728643],
#        [4.48241206],
#        [4.50753769],
#        [4.53266332],
#        [4.55778894],
#        [4.58291457],
#        [4.6080402 ],
#        [4.63316583],
#        [4.65829146],
#        [4.68341709],
#        [4.70854271],
#        [4.73366834],
#        [4.75879397],
#        [4.7839196 ],
#        [4.80904523],
#        [4.83417085],
#        [4.85929648],
#        [4.88442211],
#        [4.90954774],
#        [4.93467337],
#        [4.95979899],
#        [4.98492462],
#        [5.01005025],
#        [5.03517588],
#        [5.06030151],
#        [5.08542714],
#        [5.11055276],
#        [5.13567839],
#        [5.16080402],
#        [5.18592965],
#        [5.21105528],
#        [5.2361809 ],
#        [5.26130653],
#        [5.28643216],
#        [5.31155779],
#        [5.33668342],
#        [5.36180905],
#        [5.38693467],
#        [5.4120603 ],
#        [5.43718593],
#        [5.46231156],
#        [5.48743719],
#        [5.51256281],
#        [5.53768844],
#        [5.56281407],
#        [5.5879397 ],
#        [5.61306533],
#        [5.63819095],
#        [5.66331658],
#        [5.68844221],
#        [5.71356784],
#        [5.73869347],
#        [5.7638191 ],
#        [5.78894472],
#        [5.81407035],
#        [5.83919598],
#        [5.86432161],
#        [5.88944724],
#        [5.91457286],
#        [5.93969849],
#        [5.96482412],
#        [5.98994975],
#        [6.01507538],
#        [6.04020101],
#        [6.06532663],
#        [6.09045226],
#        [6.11557789],
#        [6.14070352],
#        [6.16582915],
#        [6.19095477],
#        [6.2160804 ],
#        [6.24120603],
#        [6.26633166],
#        [6.29145729],
#        [6.31658291],
#        [6.34170854],
#        [6.36683417],
#        [6.3919598 ],
#        [6.41708543],
#        [6.44221106],
#        [6.46733668],
#        [6.49246231],
#        [6.51758794],
#        [6.54271357],
#        [6.5678392 ],
#        [6.59296482],
#        [6.61809045],
#        [6.64321608],
#        [6.66834171],
#        [6.69346734],
#        [6.71859296],
#        [6.74371859],
#        [6.76884422],
#        [6.79396985],
#        [6.81909548],
#        [6.84422111],
#        [6.86934673],
#        [6.89447236],
#        [6.91959799],
#        [6.94472362],
#        [6.96984925],
#        [6.99497487],
#        [7.0201005 ],
#        [7.04522613],
#        [7.07035176],
#        [7.09547739],
#        [7.12060302],
#        [7.14572864],
#        [7.17085427],
#        [7.1959799 ],
#        [7.22110553],
#        [7.24623116],
#        [7.27135678],
#        [7.29648241],
#        [7.32160804],
#        [7.34673367],
#        [7.3718593 ],
#        [7.39698492],
#        [7.42211055],
#        [7.44723618],
#        [7.47236181],
#        [7.49748744],
#        [7.52261307],
#        [7.54773869],
#        [7.57286432],
#        [7.59798995],
#        [7.62311558],
#        [7.64824121],
#        [7.67336683],
#        [7.69849246],
#        [7.72361809],
#        [7.74874372],
#        [7.77386935],
#        [7.79899497],
#        [7.8241206 ],
#        [7.84924623],
#        [7.87437186],
#        [7.89949749],
#        [7.92462312],
#        [7.94974874],
#        [7.97487437],
#        [8.        ]])

# %%
ypred = model.predict(dummy_x)

# %%
raihan = visualization(x_train[['CYLINDERS']],y_train,dummy_x,ypred,"CYLINDERS")
raihan.visualize()
