# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib notebook
import seaborn as sns

# %%
source = 'https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data'
columns = ['sepal length','sepal width','petal length','petal width','species']
df = pd.read_csv(source,names = columns)

df
# Out:
#      sepal length  sepal width  petal length  petal width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df.corr()
# Out:
#               sepal length  sepal width  petal length  petal width
# sepal length      1.000000    -0.109369      0.871754     0.817954
# sepal width      -0.109369     1.000000     -0.420516    -0.356544
# petal length      0.871754    -0.420516      1.000000     0.962757
# petal width       0.817954    -0.356544      0.962757     1.000000

# %%
sns.heatmap(df.corr(),annot = True,linecolor='white')
# Out:
# <img src="data:image/png;base64,..." width="640">
# <AxesSubplot:>

# %%
sns.heatmap(df.corr(),annot = True,cmap = 'BuPu')
# Out:
# <img src="data:image/png;base64,..." width="640">
# <AxesSubplot:>

# %%
sns.scatterplot(data = df,x='petal length',y='petal width', hue = 'species',palette='Set2')
# Out:
# <img src="data:image/png;base64,..." width="640">
# <AxesSubplot:xlabel='petal length', ylabel='petal width'>

# %%
sns.set(style = 'darkgrid')
sns.scatterplot(data = df,x='petal length',y='petal width', hue = 'species',palette='Set2')
# Out:
# <img src="data:image/png;base64,..." width="640">
# <AxesSubplot:xlabel='petal length', ylabel='petal width'>

# %%
sns.lineplot(data = df,x='petal length',y='petal width', hue = 'species',palette='Set2')
# Out:
# <img src="data:image/png;base64,..." width="640">
# <AxesSubplot:xlabel='petal length', ylabel='petal width'>

# %%
sns.histplot(data = df,x='petal length')
# Out:
# <img src="data:image/png;base64,..." width="640">
# <AxesSubplot:xlabel='petal length', ylabel='Count'>

# %%
sns.boxplot(data=df)
# Out:
# <img src="data:image/png;base64,..." width="640">
# <AxesSubplot:>

# %%
sns.pairplot(df, kind="scatter", hue="species", markers=["o", "s", "D"], palette="Set2")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1432">
